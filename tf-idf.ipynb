# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from ctfidf import CTFIDFVectorizer

# %%
references_df = pd.read_pickle("pandas_data.pkl")
df=references_df[["id","abstract"]]

# %%
dt=pd.read_pickle("clustered_embeddings_df_test.pkl")

# %%
docs=dt[["id","cluster_hamed","cluster_d2v"]].merge(df,how='inner', on="id")
docs=docs.dropna()
docs1=docs[docs["cluster_hamed"]!=-1]
docs2=docs[docs["cluster_d2v"]!=-1]

# %%
docs2
# Out:
#                               id  cluster_hamed  cluster_d2v  \
# 0       53e99792b7602d9701f5b074             -1          362
# 1       53e99792b7602d9701f5b0c6             -1          650
# 3       53e997b2b7602d9701f94f82             -1          611
# 4       53e997bdb7602d9701fa70a1             -1          582
# 6       53e997cbb7602d9701fbd35a             -1          494
# ...                          ...            ...          ...
# 167306  603768b2d3485cfff1dd9724            250          232
# 167308  6037695fd3485cfff1de8505            337          275
# 167310  603769ebd3485cfff1df496d             -1          638
# 167311  60376a9fd3485cfff1e04286            250          232
# 167312  60376ac3d3485cfff1e073a8             -1          511
#
#                                                  abstract
# 0       Yalut is a novel user-centric hybrid content s...
# 1       Although different kinds of probabilistic π-ca...
# 3       A main challenge in today's embedded system de...
# 4       We show that if a flow network has k input/out...
# 6       - The aim of this paper is to propose a novel ...
# ...                                                   ...
# 167306  We study the pricing and hedging of derivative...
# 167308  This paper studies the ability of competing re...
# 167310  The ongoing fragmentation of work. has resulte...
# 167311  We consider dynamic asset allocation problems ...
# 167312  In cargo logistics, a key performance measure ...
#
# [87685 rows x 4 columns]

# %%
docs_per_class1 = docs1.groupby(['cluster_hamed'], as_index=False).agg({'abstract': ' '.join})
docs_per_class2 = docs2.groupby(['cluster_d2v'], as_index=False).agg({'abstract': ' '.join})

# %%
# Create bag of words
count_vectorizer1 = CountVectorizer().fit(docs_per_class1.abstract)
words1 = count_vectorizer1.get_feature_names()
# Create c-TF-IDF
count1 = count_vectorizer1.transform(docs_per_class1.abstract)
ctfidf1 = CTFIDFVectorizer().fit_transform(count1, n_samples=len(docs1)).toarray()

# %%
# Create bag of words
count_vectorizer2 = CountVectorizer().fit(docs_per_class2.abstract)
words2 = count_vectorizer2.get_feature_names()
# Create c-TF-IDF
count2 = count_vectorizer2.transform(docs_per_class2.abstract)
ctfidf2 = CTFIDFVectorizer().fit_transform(count2, n_samples=len(docs2)).toarray()

# %%
topics1=[]
for label in docs_per_class1.cluster_hamed:
    topic=[]
    for index in ctfidf1[label].argsort()[-10:]:
        topic.append(words1[index])
    topics1.append(topic)
    #print(label,topic)

# %%
topics2=[]
for label in docs_per_class2.cluster_d2v:
    topic=[]
    for index in ctfidf2[label].argsort()[-10:]:
        topic.append(words2[index])
    topics2.append(topic)
    #print(label,topic)

# %%
topics1
# Out:
# [['col',
#   'first',
#   'monograph',
#   '1561',
#   'economic',
#   '1300000011',
#   'h4',
#   'div',
#   'article',
#   'page'],
#  ['für', 'den', 'auf', 'eine', 'zu', 'werden', 'von', 'die', 'der', 'und'],
#  ['chinese',
#   'highlights',
#   'developments',
#   'japan',
#   'rec',
#   'kanji',
#   'character',
#   'ognition',
#   'decade',
#   'technical'],
#  ['un', 'du', 'dans', 'en', 'le', 'une', 'des', 'les', 'la', 'de'],
#  ['former',
#   'release',
#   '2007',
#   'extensible',
#   'rewrite',
#   'gt',
#   'fabrics',
#   'sep',
#   'ogsa',
#   'dai'],
#  ['crisis',
#   'ss',
#   'demonstration',
#   'backend',
#   'l3np',
#   'granularity',
#   'iag',
#   'wimax',
#   'article',
#   'page'],
#  ['printing',
#   'covers',
#   'geography',
#   'guards',
#   'ivt',
#   'available',
#   'no',
#   'aer',
#   'abstract',
#   'gallery'],
#  ['algorithmic',
#   'quic',
#   'scalability',
#   'farms',
#   'identifiers',
#   'internet',
#   'una',
#   'pwlan',
#   'article',
#   'page'],
#  ['specialized',
#   'transport',
#   'port',
#   'skill',
#   'rulesets',
#   'incidents',
#   'itt',
#   'nids',
#   'article',
#   'page'],
#  ['mcs',
#   'grade',
#   'pedigrees',
#   'flow',
#   'commodity',
#   'ifd',
#   'multistate',
#   'without',
#   'reliability',
#   'abstract'],
#  ['character',
#   'characters',
#   'humans',
#   'apart',
#   'turing',
#   'automated',
#   'tell',
#   'bots',
#   'captchas',
#   'captcha'],
#  ['moves',
#   'placing',
#   'configuration',
#   'vertices',
#   'lemke',
#   'solvable',
#   'vertex',
#   'pebble',
#   'pebbling',
#   'pebbles'],
#  ['nanomachine',
#   'mc',
#   'receiver',
#   'symbol',
#   'transmitter',
#   'diffusion',
#   'nanomachines',
#   'nano',
#   'molecules',
#   'molecular'],
#  ['reconstruction',
#   'mat',
#   'electrodes',
#   'imaging',
#   'mreit',
#   'tomography',
#   'electrical',
#   'impedance',
#   'conductivity',
#   'eit'],
#  ['transplantation',
#   'nn',
#   'base',
#   'knowledge',
#   'similarity',
#   'cases',
#   'adaptation',
#   'case',
#   'reasoning',
#   'cbr'],
#  ['infobutton',
#   'chtn',
#   'mcf',
#   'facility',
#   'handhold',
#   'dcn',
#   'breakaway',
#   'moorepenrose',
#   'without',
#   'abstract'],
#  ['rf',
#   'indoor',
#   'lifi',
#   'emitting',
#   'optical',
#   'leds',
#   'led',
#   'visible',
#   'light',
#   'vlc'],
#  ['dl',
#   'mg',
#   'mellitus',
#   'patient',
#   'diabetic',
#   'meal',
#   'blood',
#   'diabetes',
#   'insulin',
#   'glucose'],
#  ['inefficiency',
#   'efficiencies',
#   'inputs',
#   'dmu',
#   'frontier',
#   'outputs',
#   'efficiency',
#   'dmus',
#   'envelopment',
#   'dea'],
#  ['workers',
#   'privacy',
#   'incentive',
#   'participants',
#   'mobile',
#   'crowd',
#   'participatory',
#   'mcs',
#   'crowdsensing',
#   'sensing'],
#  ['feed',
#   'roughness',
#   'axis',
#   'surface',
#   'workpiece',
#   'milling',
#   'cutter',
#   'tool',
#   'machining',
#   'cutting'],
#  ['aercs',
#   'imaep',
#   'aaercs',
#   'dongle',
#   'usb',
#   'vospa',
#   'tether',
#   'mmae',
#   'article',
#   'page'],
#  ['reader',
#   'protocols',
#   'ownership',
#   'security',
#   'protocol',
#   'privacy',
#   'authentication',
#   'tag',
#   'tags',
#   'rfid'],
#  ['strength',
#   'reader',
#   'jumploc',
#   'uhf',
#   'rssi',
#   'passive',
#   'localization',
#   'tags',
#   'tag',
#   'rfid'],
#  ['passive',
#   'slots',
#   'uhf',
#   'identification',
#   'collision',
#   'readers',
#   'reader',
#   'tag',
#   'tags',
#   'rfid'],
#  ['aoa',
#   'ranging',
#   'indoor',
#   'los',
#   'arrival',
#   'positioning',
#   'localization',
#   'sight',
#   'toa',
#   'nlos'],
#  ['anchor',
#   'wifi',
#   'position',
#   'strength',
#   'location',
#   'rssi',
#   'rss',
#   'positioning',
#   'indoor',
#   'localization'],
#  ['metis',
#   'subnetwork',
#   'jostle',
#   'uncoarsening',
#   'pagrid',
#   'partitions',
#   'multilevel',
#   'subnetworks',
#   'partitioner',
#   'partitioning'],
#  ['snap',
#   'evident',
#   'exclusion',
#   'tamper',
#   'daemon',
#   'self',
#   'election',
#   'leader',
#   'stabilization',
#   'stabilizing'],
#  ['nhl',
#   'coconut',
#   'fuzzy',
#   'map',
#   'causal',
#   'cotton',
#   'maps',
#   'cognitive',
#   'fcms',
#   'fcm'],
#  ['social',
#   'agents',
#   'ratings',
#   'malicious',
#   'trustworthy',
#   'peer',
#   'peers',
#   'trustworthiness',
#   'reputation',
#   'trust'],
#  ['crossbars',
#   'circuit',
#   'neuromorphic',
#   'cmos',
#   'spice',
#   'emulator',
#   'memristors',
#   'crossbar',
#   'memristive',
#   'memristor'],
#  ['rsp',
#   'rpe',
#   'hr',
#   'medicated',
#   'adhd',
#   'skin',
#   'galvanic',
#   'physiological',
#   'gsr',
#   'stress'],
#  ['enhancements',
#   'timed',
#   'djvu',
#   'stratification',
#   'n2n',
#   'belongs',
#   'universalconstraint',
#   'lad',
#   'navigable',
#   'quot'],
#  ['secure',
#   'silicon',
#   'physically',
#   'counterfeiting',
#   'ud',
#   'physical',
#   'sram',
#   'unclonable',
#   'pufs',
#   'puf'],
#  ['decoy',
#   'authentication',
#   'classical',
#   'security',
#   'eavesdroppers',
#   'cryptographic',
#   'mdi',
#   'key',
#   'quantum',
#   'qkd'],
#  ['liquidity',
#   'enterprises',
#   'risk',
#   'interbank',
#   'bank',
#   'financial',
#   'banks',
#   'credit',
#   'contagion',
#   'systemic'],
#  ['nuisance',
#   'quality',
#   'cdq',
#   'deadband',
#   'zillow',
#   'disinformation',
#   'geocoding',
#   'conceptual',
#   'without',
#   'abstract'],
#  ['parishes',
#   'gam',
#   'migrant',
#   'offender',
#   'criminal',
#   'offenders',
#   'violent',
#   'police',
#   'crimes',
#   'crime'],
#  ['verifiability',
#   'ballot',
#   'ballots',
#   'voter',
#   'elections',
#   'election',
#   'votes',
#   'vote',
#   'voters',
#   'voting'],
#  ['memory',
#   'addressable',
#   'trie',
#   'tables',
#   'ip',
#   'prefix',
#   'packet',
#   'table',
#   'tcam',
#   'lookup'],
#  ['targeting',
#   'revenue',
#   'sponsored',
#   'clicks',
#   'advertiser',
#   'ad',
#   'click',
#   'advertisers',
#   'ads',
#   'advertising'],
#  ['best',
#   'ranking',
#   'conjugacy',
#   'alternatives',
#   'budget',
#   'ocba',
#   'selection',
#   'designs',
#   'selecting',
#   'procedures'],
#  ['practice',
#   'cpgs',
#   'lassie',
#   'ygrc',
#   'cig',
#   'proforma',
#   'recommendations',
#   'clinical',
#   'guidelines',
#   'guideline'],
#  ['apriori',
#   'pattern',
#   'itemset',
#   'rule',
#   'patterns',
#   'rules',
#   'association',
#   'itemsets',
#   'frequent',
#   'mining'],
#  ['channel',
#   'channels',
#   'solomon',
#   'progressive',
#   'coding',
#   'transmission',
#   'video',
#   'protection',
#   'unequal',
#   'uep'],
#  ['camera',
#   'digital',
#   'splicing',
#   'forgeries',
#   'jpeg',
#   'forensics',
#   'tampered',
#   'forensic',
#   'forgery',
#   'tampering'],
#  ['tracing',
#   'multimedia',
#   'colluder',
#   'attack',
#   'copies',
#   'codes',
#   'fingerprints',
#   'colluders',
#   'collusion',
#   'fingerprinting'],
#  ['copyright',
#   'audio',
#   'robustness',
#   'digital',
#   'attacks',
#   'watermarks',
#   'watermarked',
#   'embedding',
#   'watermark',
#   'watermarking'],
#  ['capacity',
#   'pee',
#   'pixels',
#   'encrypted',
#   'histogram',
#   'secret',
#   'rdh',
#   'embedding',
#   'reversible',
#   'hiding'],
#  ['bits',
#   'cover',
#   'lsb',
#   'secret',
#   'steganographic',
#   'hiding',
#   'stego',
#   'embedding',
#   'steganalysis',
#   'steganography'],
#  ['masse',
#   'spying',
#   'mole',
#   'execution',
#   'ma',
#   'security',
#   'hosts',
#   'mobile',
#   'agents',
#   'agent'],
#  ['hypercube',
#   'designs',
#   'uncertainty',
#   'metamodeling',
#   'latin',
#   'hdmr',
#   'metamodel',
#   'metamodels',
#   'sensitivity',
#   'kriging'],
#  ['cavity',
#   'cbct',
#   'segmentation',
#   'crown',
#   'occlusal',
#   'orthodontic',
#   'radiographs',
#   'dental',
#   'teeth',
#   'tooth'],
#  ['economy',
#   'emissions',
#   'powertrain',
#   'diesel',
#   'drive',
#   'engine',
#   'vehicle',
#   'electric',
#   'fuel',
#   'hev'],
#  ['routing',
#   'constellations',
#   'dvb',
#   'constellation',
#   'isl',
#   'earth',
#   'satellites',
#   'orbit',
#   'satellite',
#   'leo'],
#  ['sa',
#   'human',
#   'trust',
#   'driver',
#   'warning',
#   'driving',
#   'drivers',
#   'situation',
#   'awareness',
#   'automation'],
#  ['bandwidth',
#   'packet',
#   'layer',
#   'loss',
#   'broadcast',
#   'correction',
#   'multicast',
#   'arq',
#   'video',
#   'fec'],
#  ['fork',
#   'dace',
#   'global',
#   'globalizer',
#   'ua',
#   'qtfds',
#   'flim',
#   'prngs',
#   'sce',
#   'mads'],
#  ['record',
#   'electronic',
#   'health',
#   'emrs',
#   'notes',
#   'records',
#   'patient',
#   'medical',
#   'ehr',
#   'clinical'],
#  ['treatment',
#   'immune',
#   'drug',
#   'cd4',
#   'infected',
#   'therapy',
#   'virus',
#   'viral',
#   'hiv',
#   'infection'],
#  ['prefix',
#   'log',
#   'text',
#   'length',
#   'compressed',
#   'alphabet',
#   'suffix',
#   'compression',
#   'strings',
#   'string'],
#  ['liposomes',
#   'minute',
#   'lighting',
#   'allpass',
#   'amos',
#   'mlm',
#   'qoc',
#   'influent',
#   'without',
#   'abstract'],
#  ['concurrent',
#   'riese',
#   'kaucher',
#   'paule',
#   'ud',
#   'without',
#   'controllability',
#   'pls',
#   'surrogate',
#   'abstract'],
#  ['interoperability',
#   'conversational',
#   'persuasive',
#   'netbytes',
#   'setu',
#   'pdf',
#   'usher',
#   'documents',
#   'article',
#   'page'],
#  ['investigations',
#   'cloud',
#   'investigation',
#   'criminal',
#   'investigators',
#   'lucid',
#   'digital',
#   'evidence',
#   'forensics',
#   'forensic'],
#  ['neurons',
#   'neural',
#   'clustering',
#   'soms',
#   'maps',
#   'kohonen',
#   'map',
#   'self',
#   'organizing',
#   'som'],
#  ['isocialmash',
#   'browser',
#   'omash',
#   'spreadsheet',
#   'composition',
#   'developers',
#   'web',
#   'apis',
#   'mashups',
#   'mashup'],
#  ['labels',
#   'sanctioning',
#   'crowds',
#   'answers',
#   'sourcing',
#   'tasks',
#   'worker',
#   'crowd',
#   'workers',
#   'crowdsourcing'],
#  ['bankers',
#   'ricf',
#   'pdlc',
#   'pepper',
#   'patrol',
#   '12',
#   'ghost',
#   'style',
#   'without',
#   'abstract'],
#  ['role',
#   'roles',
#   'xacml',
#   'delegation',
#   'security',
#   'authorization',
#   'access',
#   'policy',
#   'rbac',
#   'policies'],
#  ['correct',
#   'incorrectly',
#   'see',
#   'incorrect',
#   'no',
#   'above',
#   'titled',
#   'pp',
#   'ibid',
#   'vol'],
#  ['ebg',
#   'scattering',
#   'electromagnetic',
#   'radar',
#   'metal',
#   'subsurface',
#   'ground',
#   'buried',
#   'penetrating',
#   'gpr'],
#  ['demographies',
#   'swfft',
#   'homeorhesis',
#   'enterotypes',
#   'history',
#   'deskew',
#   'alfa',
#   'rosser',
#   'without',
#   'abstract'],
#  ['engineering',
#   'panel',
#   'presentations',
#   'acm',
#   'papers',
#   'symposium',
#   'held',
#   'international',
#   'conference',
#   'workshop'],
#  ['institutes',
#   'vocabulary',
#   'games',
#   'empty',
#   'chat',
#   'traveling',
#   'salesman',
#   'without',
#   'provenance',
#   'abstract'],
#  ['reviewers',
#   'releasable',
#   'abstract',
#   'pool',
#   'heuristiclab',
#   'dss',
#   'mts',
#   'nhsom',
#   'release',
#   'ca2'],
#  ['rfp',
#   'drainage',
#   'visualization',
#   'run',
#   'dinam',
#   'ucc',
#   'worlds',
#   'grey',
#   'without',
#   'abstract'],
#  ['tonk',
#   'canal',
#   'token',
#   'bags',
#   'metrology',
#   'prototyping',
#   'laptops',
#   'semiconductor',
#   'without',
#   'abstract'],
#  ['habermas',
#   'unicon',
#   'campus',
#   'emancipation',
#   'no',
#   'available',
#   'percept',
#   'storage',
#   'abstract',
#   'feminist'],
#  ['controllers',
#   'color',
#   'crane',
#   'characteristic',
#   'mask',
#   'yard',
#   'without',
#   'osek',
#   'noh',
#   'abstract'],
#  ['specification',
#   'gspn',
#   'branched',
#   'parallel',
#   'webkb',
#   'hct',
#   'prm',
#   'net',
#   'without',
#   'abstract'],
#  ['inconvenience',
#   'pseudo',
#   'tells',
#   'conceivable',
#   'touchscreens',
#   'nonbipartite',
#   'median',
#   'smartphones',
#   'without',
#   'abstract'],
#  ['formal',
#   'objectoriented',
#   'actors',
#   'acyclic',
#   'behavioral',
#   'fsaf',
#   'horn',
#   'without',
#   'gel',
#   'abstract'],
#  ['ecological',
#   'behaviours',
#   'plausible',
#   'qualitatively',
#   'bucciarelli',
#   'antonio',
#   'ofstrong',
#   'sequentialitywritten',
#   'without',
#   'abstract'],
#  ['verge',
#   'laboratory',
#   'miller',
#   'crane',
#   'standardised',
#   'electromagnet',
#   'options',
#   'enkf',
#   'without',
#   'abstract'],
#  ['tl',
#   'modeling',
#   'modelica',
#   'fixation',
#   'fern',
#   'reaction',
#   'pulse',
#   'forestry',
#   'without',
#   'abstract'],
#  ['primary',
#   'textures',
#   'clairvoyance',
#   'psychophysical',
#   'lines',
#   'r3t',
#   'segregation',
#   'kehrer',
#   'without',
#   'abstract'],
#  ['latest',
#   'residential',
#   'workflow',
#   'poster',
#   'freight',
#   'reshaping',
#   'without',
#   'argos',
#   'costas',
#   'abstract'],
#  ['animated',
#   'transformation',
#   'subdivided',
#   'ada',
#   'transitions',
#   'sam',
#   'shot',
#   'dtmf',
#   'without',
#   'abstract'],
#  ['anomalous',
#   'mission',
#   'sc',
#   'plan',
#   'tem',
#   'dnro',
#   'diffusion',
#   'nro',
#   'without',
#   'abstract'],
#  ['vented',
#   'resurveyed',
#   'report',
#   'without',
#   'tra',
#   'interprocedural',
#   'rst',
#   'questionaire',
#   'faults',
#   'abstract'],
#  ['γp',
#   'exponentially',
#   'hofstadter',
#   'vickrey',
#   'rn',
#   'radiant',
#   'harness',
#   'metacomputing',
#   'without',
#   'abstract'],
#  ['reproduction',
#   'city',
#   'inquiry',
#   'grammatical',
#   'without',
#   'noninterference',
#   'replay',
#   'ungrammatical',
#   'infocity',
#   'abstract'],
#  ['sam',
#   'easily',
#   'fem',
#   'mediation',
#   'gid',
#   'restitution',
#   'washout',
#   'without',
#   'feelfem',
#   'abstract'],
#  ['rrs',
#   'virtual',
#   'srt',
#   'hazop',
#   'japanese',
#   'characters',
#   'neoplasia',
#   'colonoscopy',
#   'article',
#   'page'],
#  ['layout',
#   'display',
#   'visualisation',
#   'views',
#   'exploration',
#   'analytics',
#   'interactive',
#   'visual',
#   'visualizations',
#   'visualization'],
#  ['outward',
#   'bar',
#   'corner',
#   'compensation',
#   'ga',
#   'etch',
#   '25wt',
#   'tmah',
#   'without',
#   'abstract'],
#  ['avert',
#   'gratified',
#   'quine',
#   'without',
#   'ploc',
#   'socializing',
#   'pulse',
#   'pulsed',
#   'ccl',
#   'abstract'],
#  ['distance',
#   'facilities',
#   'tu',
#   'barriers',
#   'momp',
#   'facility',
#   'abstract',
#   'electoral',
#   'barrier',
#   'districting'],
#  ['battlefield',
#   'coupling',
#   'procedural',
#   'tion',
#   'tiles',
#   'specification',
#   'opt',
#   'without',
#   'hdl',
#   'abstract'],
#  ['cohen',
#   'cation',
#   'passband',
#   'contextualization',
#   'podnieks',
#   'barzdin',
#   'speci',
#   'kernel',
#   'without',
#   'abstract'],
#  ['tuned',
#   'programmers',
#   'stay',
#   'marriage',
#   'unix',
#   'operand',
#   'smalltalk',
#   'la',
#   'without',
#   'abstract'],
#  ['offsetting',
#   'procedures',
#   'proce',
#   'semantics',
#   'without',
#   'workflow',
#   'sound',
#   'sounds',
#   'abstract',
#   'wfmss'],
#  ['ads',
#   'sats',
#   'pilots',
#   'flight',
#   'flare',
#   'aeromacs',
#   'airspace',
#   'air',
#   'landing',
#   'aircraft'],
#  ['pertinentproperties',
#   'nested',
#   'fisheye',
#   'elision',
#   'without',
#   'proteomics',
#   'nv3d',
#   'depositions',
#   'pride',
#   'abstract'],
#  ['surprisal',
#   'passengers',
#   'wheezing',
#   'ritual',
#   'fixture',
#   'street',
#   'workload',
#   'religious',
#   'article',
#   'page'],
#  ['cultural',
#   'intermediate',
#   'specifications',
#   'opcodes',
#   'heritage',
#   'ivf',
#   'without',
#   'rarrk',
#   'opcode',
#   'abstract'],
#  ['gilbert',
#   'nfes',
#   'leukemic',
#   'wip',
#   'san',
#   'streams',
#   'halftoning',
#   'rids',
#   'without',
#   'abstract'],
#  ['sipe',
#   'schedule',
#   'connector',
#   'performability',
#   'doctor',
#   'ne',
#   'mscs',
#   'thinglab',
#   'without',
#   'abstract'],
#  ['machine',
#   'computer',
#   'concurrent',
#   'ask',
#   'upcall',
#   'downcall',
#   'synchronous',
#   'desktop',
#   'without',
#   'abstract'],
#  ['incomplete',
#   'chemical',
#   'kinetics',
#   'iq',
#   'manifolds',
#   'ann',
#   'iqms',
#   'slow',
#   'without',
#   'abstract'],
#  ['zigbee',
#   'positioning',
#   'without',
#   'preview',
#   '4000',
#   'deductive',
#   'fiber',
#   'lamost',
#   'tau',
#   'abstract'],
#  ['mercury',
#   'focal',
#   'scr',
#   'desulfurization',
#   'gypsum',
#   'musa',
#   'without',
#   'dmp',
#   'schemas',
#   'abstract'],
#  ['itsgeneralizations',
#   'transitivity',
#   'excluding',
#   'java',
#   'di',
#   'overlaps',
#   'utterances',
#   'without',
#   'δi',
#   'abstract'],
#  ['gricean',
#   'spontaneous',
#   'felicitousness',
#   'biosignalsstudio',
#   'semantico',
#   'giorgolo',
#   'multimodal',
#   'pragmatic',
#   'without',
#   'abstract'],
#  ['product',
#   'ugc',
#   'creation',
#   'commerce',
#   'reading',
#   'layout',
#   'logiweb',
#   'pages',
#   'article',
#   'page'],
#  ['das',
#   'automation',
#   'fsss',
#   'am',
#   'x3d',
#   'web',
#   'sociality',
#   'inspirational',
#   'article',
#   'page'],
#  ['synthesis',
#   'circuit',
#   'dot',
#   'logic',
#   'quantum',
#   'gate',
#   'circuits',
#   'gates',
#   'qca',
#   'reversible'],
#  ['bandlimited',
#   'lms',
#   'stationarity',
#   'variograms',
#   'gft',
#   'laplacian',
#   'rls',
#   'signals',
#   'graph',
#   'sampling'],
#  ['subcellular',
#   'cfgs',
#   'paj',
#   'goms',
#   'wlgauge',
#   'vopd',
#   'magnification',
#   'no',
#   'available',
#   'abstract'],
#  ['reproducible',
#   'clinical',
#   'neuropsychological',
#   'bigraph',
#   'neuropsychology',
#   'you',
#   'no',
#   'available',
#   'abstract',
#   'cbna'],
#  ['cn',
#   'no',
#   'available',
#   'en',
#   'oed',
#   'spacecraft',
#   'abstract',
#   'user1',
#   'learnability',
#   'reconfigurability'],
#  ['content',
#   'aware',
#   'depth',
#   'visually',
#   'resized',
#   'salient',
#   'carving',
#   'seam',
#   'resizing',
#   'retargeting'],
#  ['rule',
#   'discounting',
#   'fusion',
#   'evidential',
#   'theory',
#   'uncertainty',
#   'evidence',
#   'shafer',
#   'belief',
#   'dempster'],
#  ['matching',
#   'indexing',
#   'kite',
#   'submap',
#   'graph',
#   'median',
#   'edit',
#   'isomorphism',
#   'graphs',
#   'subgraph'],
#  ['unit',
#   'reliability',
#   'inspection',
#   'degradation',
#   'replacement',
#   'preventive',
#   'repairable',
#   'failure',
#   'repair',
#   'maintenance'],
#  ['machinery',
#   'prognosis',
#   'lithium',
#   'prognostic',
#   'life',
#   'prediction',
#   'remaining',
#   'prognostics',
#   'degradation',
#   'rul'],
#  ['submodels',
#   'hannibal',
#   'dagon',
#   'available',
#   'dosage',
#   'no',
#   'abstract',
#   'brix',
#   'heterarchical',
#   'galileo'],
#  ['he',
#   'industry',
#   'goldman',
#   'defense',
#   'mfi',
#   'production',
#   'ebi',
#   'mphrs',
#   'dna',
#   'says'],
#  ['piracy',
#   'ip',
#   'hths',
#   'fabrication',
#   'circuit',
#   'hardware',
#   'ic',
#   'netlist',
#   'trojans',
#   'trojan'],
#  ['distance',
#   'neighbor',
#   'shapedtw',
#   'similarity',
#   'nearest',
#   'ucr',
#   'series',
#   'bdtw',
#   'warping',
#   'dtw'],
#  ['series',
#   'datasets',
#   'dbscan',
#   'ensemble',
#   'outliers',
#   'means',
#   'outlier',
#   'cluster',
#   'clusters',
#   'clustering'],
#  ['utility',
#   'win',
#   'automated',
#   'negotiate',
#   'negotiating',
#   'opponent',
#   'agent',
#   'agents',
#   'negotiations',
#   'negotiation'],
#  ['browsing',
#   'conceptual',
#   'concepts',
#   'attribute',
#   'attributes',
#   'lattices',
#   'formal',
#   'concept',
#   'lattice',
#   'fca'],
#  ['packets',
#   'jam',
#   'wireless',
#   'lmac',
#   'mac',
#   'anti',
#   'attacks',
#   'jammers',
#   'jammer',
#   'jamming'],
#  ['ai',
#   'goals',
#   'graphplan',
#   'pddl',
#   'actions',
#   'planner',
#   'planners',
#   'plans',
#   'plan',
#   'planning'],
#  ['impaired',
#   'heading',
#   'pages',
#   'blind',
#   'wcag',
#   'web',
#   'disabilities',
#   'websites',
#   'accessible',
#   'accessibility'],
#  ['lanes',
#   'dbbm',
#   'interconnection',
#   'switches',
#   'topologies',
#   'radix',
#   'slim',
#   'ugal',
#   'infiniband',
#   'iba'],
#  ['relays',
#   'adversary',
#   'traffic',
#   'sender',
#   'onion',
#   'privacy',
#   'attacks',
#   'anonymous',
#   'anonymity',
#   'tor'],
#  ['adaptive',
#   'mean',
#   'cancellation',
#   'square',
#   'nlms',
#   'loudspeaker',
#   'acoustic',
#   'anc',
#   'echo',
#   'lms'],
#  ['allpass',
#   'digital',
#   'vfd',
#   'response',
#   'notch',
#   'impulse',
#   'iir',
#   'filter',
#   'filters',
#   'fir'],
#  ['offline',
#   'varphi',
#   'caching',
#   'ratio',
#   'lru',
#   'paging',
#   'advice',
#   'online',
#   'request',
#   'competitive'],
#  ['matrix',
#   'likelihood',
#   'detectors',
#   'glrt',
#   'anmf',
#   'gaussian',
#   'lr',
#   'detector',
#   'covariance',
#   'clutter'],
#  ['ifir',
#   'antenna',
#   'radars',
#   'stopband',
#   'isl',
#   'mimo',
#   'beampattern',
#   'radar',
#   'waveform',
#   'waveforms'],
#  ['mismatch',
#   'sinr',
#   'array',
#   'covariance',
#   'vector',
#   'capon',
#   'beamforming',
#   'beamformers',
#   'steering',
#   'beamformer'],
#  ['covariance',
#   'music',
#   'sources',
#   'doas',
#   'estimation',
#   'arrays',
#   'direction',
#   'arrival',
#   'array',
#   'doa'],
#  ['accelerometer',
#   'dsp',
#   'phones',
#   'android',
#   'swimming',
#   'photographing',
#   'sleep',
#   'sensave',
#   'isleep',
#   'smartphone'],
#  ['home',
#   'detection',
#   'person',
#   'body',
#   'bed',
#   'activities',
#   'falling',
#   'elderly',
#   'falls',
#   'fall'],
#  ['smartphone',
#   'recognition',
#   'home',
#   'sensors',
#   'wearable',
#   'accelerometer',
#   'daily',
#   'living',
#   'activities',
#   'activity'],
#  ['gridstat',
#   'mu0026s',
#   'backup',
#   'dumas',
#   'cis',
#   'availability',
#   'fault',
#   'tolerance',
#   'dependable',
#   'dependability'],
#  ['bdft',
#   'fragmented',
#   'membership',
#   'positive',
#   'amq',
#   'hash',
#   'filter',
#   'false',
#   'filters',
#   'bloom'],
#  ['packet',
#   'regex',
#   'string',
#   'nids',
#   'nfa',
#   'intrusion',
#   'regular',
#   'matching',
#   'dfa',
#   'snort'],
#  ['ftznn',
#   'zhang',
#   'recurrent',
#   'vg',
#   'neural',
#   'varying',
#   'rnn',
#   'zeroing',
#   'znd',
#   'znn'],
#  ['multiscale',
#   'remote',
#   'superpixel',
#   'fcm',
#   'speckle',
#   'unchanged',
#   'unsupervised',
#   'change',
#   'cd',
#   'multitemporal'],
#  ['glift',
#   'program',
#   'untrusted',
#   'declassification',
#   'enforce',
#   'enforcement',
#   'flow',
#   'policies',
#   'noninterference',
#   'security'],
#  ['restarting',
#   'catalytic',
#   'pgmc',
#   'eigenfrequencies',
#   'mempbpf',
#   'antiport',
#   'rules',
#   'symport',
#   'membranes',
#   'membrane'],
#  ['bands',
#   'dwt',
#   'impervious',
#   'deep',
#   'hsis',
#   'spatial',
#   'classification',
#   'spectral',
#   'hsi',
#   'hyperspectral'],
#  ['anomaly',
#   'pixel',
#   'spectra',
#   'abundances',
#   'abundance',
#   'spectral',
#   'endmember',
#   'endmembers',
#   'unmixing',
#   'hyperspectral'],
#  ['erasing',
#   'free',
#   'language',
#   'parsing',
#   'learner',
#   'tree',
#   'context',
#   'languages',
#   'grammar',
#   'grammars'],
#  ['email',
#   'websites',
#   'scams',
#   'emails',
#   'webpage',
#   'malicious',
#   'phishers',
#   'urls',
#   'webpages',
#   'phishing'],
#  ['p2p',
#   'flow',
#   'packet',
#   'udp',
#   'identification',
#   'payload',
#   'classification',
#   'flows',
#   'port',
#   'traffic'],
#  ['cloud',
#   'healthcare',
#   'technologies',
#   'city',
#   'devices',
#   'cities',
#   'internet',
#   'smart',
#   'things',
#   'iot'],
#  ['iot',
#   'edge',
#   'devices',
#   'mcc',
#   'computing',
#   'mobile',
#   'mec',
#   'cloud',
#   'fog',
#   'offloading'],
#  ['fraud',
#   'mobile',
#   'blackberry',
#   'store',
#   'android',
#   'bd',
#   'developers',
#   'reviews',
#   'app',
#   'apps'],
#  ['infrastructures',
#   'supervisory',
#   'physical',
#   'attacks',
#   'grid',
#   'attack',
#   'smart',
#   'cps',
#   'scada',
#   'cyber'],
#  ['security',
#   'graphs',
#   'defender',
#   'hardening',
#   'cyber',
#   'risk',
#   'vulnerability',
#   'attacker',
#   'attack',
#   'vulnerabilities'],
#  ['protection',
#   'sspit',
#   'trilevel',
#   'contest',
#   'fortification',
#   'game',
#   'defense',
#   'interdiction',
#   'attacker',
#   'defender'],
#  ['api',
#   'executable',
#   'signature',
#   'benign',
#   'metamorphic',
#   'virus',
#   'executables',
#   'viruses',
#   'malicious',
#   'malware'],
#  ['smartphones',
#   'mobile',
#   'benign',
#   'permission',
#   'permissions',
#   'malicious',
#   'app',
#   'apps',
#   'malware',
#   'android'],
#  ['cities',
#   'transportation',
#   'patterns',
#   'trips',
#   'travel',
#   'trip',
#   'trajectory',
#   'mobility',
#   'city',
#   'urban'],
#  ['packets',
#   'anomaly',
#   'traffic',
#   'traceback',
#   'dos',
#   'denial',
#   'attack',
#   'dns',
#   'attacks',
#   'ddos'],
#  ['inc',
#   'comput',
#   'periodicals',
#   'doi',
#   'appl',
#   'wiley',
#   '1002',
#   'eng',
#   'educ',
#   'cae'],
#  ['infected',
#   'vulnerable',
#   'infection',
#   'spread',
#   'internet',
#   'propagation',
#   'hosts',
#   'scanning',
#   'worms',
#   'worm'],
#  ['spyeye',
#   'botmaster',
#   'iot',
#   'attacks',
#   'compromised',
#   'ddos',
#   'botmasters',
#   'bots',
#   'botnets',
#   'botnet'],
#  ['self',
#   'cfb',
#   'ffb',
#   'detector',
#   'fb',
#   'antigens',
#   'intrusion',
#   'nsa',
#   'detectors',
#   'immune'],
#  ['alert',
#   'false',
#   'anomaly',
#   'detection',
#   'attack',
#   'idss',
#   'alerts',
#   'attacks',
#   'ids',
#   'intrusion'],
#  ['protection',
#   'disclosure',
#   'utility',
#   'location',
#   'sensitive',
#   'private',
#   'anonymity',
#   'preserving',
#   'anonymization',
#   'privacy'],
#  ['gates',
#   'spin',
#   'classical',
#   'unitary',
#   'qubits',
#   'states',
#   'entangled',
#   'qubit',
#   'entanglement',
#   'quantum'],
#  ['rényi',
#   'states',
#   'conditional',
#   'guesswork',
#   'nyi',
#   'shannon',
#   'quantum',
#   'entropies',
#   'renyi',
#   'entropy'],
#  ['sons',
#   'arl',
#   'run',
#   'shewhart',
#   'shifts',
#   'multivariate',
#   'cusum',
#   'ewma',
#   'charts',
#   'chart'],
#  ['variables',
#   'archimedean',
#   'marginal',
#   'vine',
#   'distributions',
#   'multivariate',
#   'bivariate',
#   'dependence',
#   'copulas',
#   'copula'],
#  ['multivariate',
#   'gaussians',
#   'variational',
#   'likelihood',
#   'mixtures',
#   'expectation',
#   'maximization',
#   'gaussian',
#   'em',
#   'mixture'],
#  ['bootstrap',
#   'mcmc',
#   'distributions',
#   'distribution',
#   'bayesian',
#   'estimator',
#   'carlo',
#   'monte',
#   'likelihood',
#   'estimators'],
#  ['map',
#   'diffusion',
#   'plain',
#   'permutation',
#   'cryptosystem',
#   'cipher',
#   'plaintext',
#   'chaos',
#   'encryption',
#   'chaotic'],
#  ['key',
#   'vsh',
#   'ntru',
#   'public',
#   'lattice',
#   'elliptic',
#   'cryptography',
#   'logarithm',
#   'cryptosystem',
#   'cryptosystems'],
#  ['modular',
#   'ecc',
#   'curves',
#   'pairing',
#   'cryptography',
#   'montgomery',
#   'gf',
#   'curve',
#   'elliptic',
#   'multiplication'],
#  ['representativeness',
#   'mapillary',
#   'import',
#   'geospatial',
#   'contributors',
#   'geographic',
#   'volunteered',
#   'openstreetmap',
#   'osm',
#   'vgi'],
#  ['fault',
#   'countermeasure',
#   'attack',
#   'side',
#   'masking',
#   'cryptographic',
#   'dpa',
#   'countermeasures',
#   'attacks',
#   'aes'],
#  ['md5',
#   'attacks',
#   '512',
#   '256',
#   'collision',
#   'attack',
#   'ripemd',
#   'preimage',
#   'sha',
#   'hash'],
#  ['box',
#   'keystream',
#   'achterbahn',
#   'generator',
#   'algebraic',
#   'boxes',
#   'ciphers',
#   'stream',
#   'cipher',
#   'attack'],
#  ['block',
#   'differential',
#   '128',
#   'attack',
#   'rounds',
#   'aes',
#   'round',
#   'cryptanalysis',
#   'cipher',
#   'ciphers'],
#  ['sharding',
#   'permissioned',
#   'ledger',
#   'iot',
#   'technology',
#   'bitcoin',
#   'blockchains',
#   'transactions',
#   'ethereum',
#   'blockchain'],
#  ['coding',
#   'compression',
#   'speech',
#   'distortion',
#   'coder',
#   'vector',
#   'lbg',
#   'quantization',
#   'codebook',
#   'vq'],
#  ['secrecy',
#   'authentication',
#   'yao',
#   'intruder',
#   'formal',
#   'dolev',
#   'security',
#   'protocol',
#   'cryptographic',
#   'protocols'],
#  ['cheating',
#   'cheaters',
#   'schemes',
#   'dealer',
#   'participants',
#   'vss',
#   'secrets',
#   'shares',
#   'sharing',
#   'secret'],
#  ['sharing',
#   'rg',
#   'visual',
#   'shadow',
#   'vss',
#   'vc',
#   'vcs',
#   'cryptography',
#   'shares',
#   'secret'],
#  ['bank',
#   'commerce',
#   'money',
#   'card',
#   'merchant',
#   'electronic',
#   'divisible',
#   'payments',
#   'payment',
#   'cash'],
#  ['ampc',
#   'fairness',
#   'multiparty',
#   'cryptographic',
#   'securely',
#   'secure',
#   'protocols',
#   'mpc',
#   'party',
#   'parties'],
#  ['possession',
#   'stored',
#   'audit',
#   'por',
#   'pdp',
#   'deduplication',
#   'integrity',
#   'storage',
#   'cloud',
#   'auditing'],
#  ['protection',
#   'shoulder',
#   'surfing',
#   'security',
#   'guessing',
#   'login',
#   'graphical',
#   'authentication',
#   'passwords',
#   'password'],
#  ['routers',
#   'forwarding',
#   'cache',
#   'networking',
#   'centric',
#   'content',
#   'ndn',
#   'caching',
#   'ccn',
#   'icn'],
#  ['key',
#   'revocation',
#   'keys',
#   'proxy',
#   'ribe',
#   'private',
#   'identity',
#   'ciphertext',
#   'ibe',
#   'encryption'],
#  ['secure',
#   'privacy',
#   'attribute',
#   'ciphertext',
#   'searchable',
#   'keyword',
#   'cloud',
#   'abe',
#   'encryption',
#   'encrypted'],
#  ['attacks',
#   'protocol',
#   'secure',
#   'card',
#   'et',
#   'al',
#   'security',
#   'attack',
#   'password',
#   'authentication'],
#  ['security',
#   'agreement',
#   'agke',
#   'exchange',
#   'secure',
#   'diffie',
#   'hellman',
#   'protocol',
#   'authenticated',
#   'key'],
#  ['security',
#   'diffie',
#   'hellman',
#   'proxy',
#   'signer',
#   'secure',
#   'rsa',
#   'encryption',
#   'signatures',
#   'signature'],
#  ['attacks',
#   'html',
#   'security',
#   'web',
#   'scripting',
#   'xss',
#   'sql',
#   'injection',
#   'php',
#   'vulnerabilities'],
#  ['updrs',
#   'tremors',
#   'motor',
#   'dyskinesia',
#   'tis',
#   'patients',
#   'disease',
#   'pd',
#   'parkinson',
#   'tremor'],
#  ['vehicles',
#   'vehicle',
#   'car',
#   'recognition',
#   'character',
#   'characters',
#   'alpr',
#   'plates',
#   'license',
#   'plate'],
#  ['gray',
#   'fic',
#   'lossless',
#   'coding',
#   'blocks',
#   'pso',
#   'hfic',
#   'encoding',
#   'compression',
#   'fractal'],
#  ['resolution',
#   'cmro2',
#   'imaging',
#   'mri',
#   'reconstructed',
#   'positron',
#   'emission',
#   'tomography',
#   'pet',
#   'reconstruction'],
#  ['lifting',
#   'dwt',
#   'transform',
#   'coder',
#   'jpeg2000',
#   'spiht',
#   'coding',
#   'lossless',
#   'wavelet',
#   'compression'],
#  ['264',
#   'rmsvc',
#   'scalability',
#   'scalable',
#   'bitstream',
#   'streaming',
#   'coding',
#   'video',
#   'svc',
#   'fgs'],
#  ['satd',
#   'coding',
#   'mdst',
#   'video',
#   'vi',
#   'idct',
#   'transform',
#   '264',
#   'cosine',
#   'dct'],
#  ['encoder',
#   'mpeg',
#   'intra',
#   'frame',
#   'avc',
#   'motion',
#   'hevc',
#   'video',
#   '264',
#   'coding'],
#  ['randomness',
#   'bpp',
#   'proof',
#   'polynomial',
#   'pseudorandom',
#   'constructions',
#   'epsilon',
#   'circuits',
#   'log',
#   'extractors'],
#  ['log',
#   'frobenius',
#   'approximation',
#   'norm',
#   'singular',
#   'svd',
#   'randomized',
#   'columns',
#   'matrix',
#   'rank'],
#  ['vqa',
#   'reference',
#   'distorted',
#   'distortion',
#   'quality',
#   'distortions',
#   'subjective',
#   'nr',
#   'assessment',
#   'iqa'],
#  ['images',
#   'spectral',
#   'sharpening',
#   'ms',
#   'pansharpening',
#   'fused',
#   'panchromatic',
#   'multispectral',
#   'pan',
#   'fusion'],
#  ['agent',
#   'influence',
#   'consensus',
#   'social',
#   'formation',
#   'dynamics',
#   'confidence',
#   'agents',
#   'opinions',
#   'opinion'],
#  ['disjoint',
#   'hamiltonian',
#   'hypercubes',
#   'cubes',
#   'diagnosability',
#   'cube',
#   'faulty',
#   'fault',
#   'interconnection',
#   'hypercube'],
#  ['pwvd',
#   'frequency',
#   'fourier',
#   'ville',
#   'wvd',
#   'adtfd',
#   'prsa',
#   'stft',
#   'wigner',
#   'spectrogram'],
#  ['spread',
#   'susceptible',
#   'contact',
#   'infection',
#   'viruses',
#   'sis',
#   'infected',
#   'spreading',
#   'virus',
#   'epidemic'],
#  ['outbreak',
#   'spread',
#   'infection',
#   'infectious',
#   'pandemic',
#   'epidemic',
#   'vaccine',
#   'disease',
#   'influenza',
#   'vaccination'],
#  ['exposed',
#   'images',
#   'luminance',
#   'color',
#   'exposure',
#   'range',
#   'mapping',
#   'ldr',
#   'tone',
#   'hdr'],
#  ['cameras',
#   'cfas',
#   'pixels',
#   'rgbw',
#   'bayer',
#   'interpolation',
#   'demosaicking',
#   'cfa',
#   'demosaicing',
#   'color'],
#  ['nodesketch',
#   'learn',
#   'metagraphs',
#   'node',
#   'centrality',
#   'metapath2vec',
#   'representations',
#   'hin',
#   'embedding',
#   'embeddings'],
#  ['world',
#   'nodes',
#   'influential',
#   'osns',
#   'degree',
#   'influence',
#   'centrality',
#   'communities',
#   'social',
#   'community'],
#  ['contourlet',
#   'blrnn',
#   'mdfb',
#   'filter',
#   'lifting',
#   'cwt',
#   'spline',
#   'transform',
#   'wavelets',
#   'wavelet'],
#  ['dark',
#   'atmospheric',
#   'foggy',
#   'color',
#   'light',
#   'fog',
#   'hazy',
#   'underwater',
#   'dehazing',
#   'haze'],
#  ['details',
#   'brightness',
#   'histograms',
#   'gamma',
#   'light',
#   'stripe',
#   'equalization',
#   'contrast',
#   'histogram',
#   'enhancement'],
#  ['schaefer',
#   'qcsp',
#   'infinite',
#   'consistency',
#   'csps',
#   'tractable',
#   'csp',
#   'dichotomy',
#   'satisfaction',
#   'constraint'],
#  ['radar',
#   'moisture',
#   'forest',
#   'sar',
#   'modis',
#   'satellite',
#   'soil',
#   'water',
#   'land',
#   'vegetation'],
#  ['thresholding',
#   'noise',
#   'chmt',
#   'transform',
#   'wavelets',
#   'hmt',
#   'ridgelet',
#   'coefficients',
#   'wavelet',
#   'denoising'],
#  ['signal',
#   'pursuit',
#   'sparsity',
#   'reconstruction',
#   'compressed',
#   'recovery',
#   'sensing',
#   'cs',
#   'compressive',
#   'sparse'],
#  ['squint',
#   'range',
#   'bistatic',
#   'doppler',
#   'imaging',
#   'synthetic',
#   'radar',
#   'aperture',
#   'azimuth',
#   'sar'],
#  ['inverse',
#   'synthetic',
#   'maneuvering',
#   'target',
#   'targets',
#   'aperture',
#   'doppler',
#   'imaging',
#   'radar',
#   'isar'],
#  ['canonical',
#   'signals',
#   'dcft',
#   'lfm',
#   'fractional',
#   'frft',
#   'transform',
#   'lct',
#   'fourier',
#   'chirp'],
#  ['lensless',
#   'convolutional',
#   'lso',
#   'residual',
#   'sisr',
#   'lr',
#   'bird',
#   'resolution',
#   'super',
#   'sr'],
#  ['rnns',
#   'dfsta',
#   'prnn',
#   'symbolic',
#   'articulation',
#   'srn',
#   'neural',
#   'smrnn',
#   'recurrent',
#   'rnn'],
#  ['dictionary',
#   'patch',
#   'interpolation',
#   'reconstruction',
#   'patches',
#   'lr',
#   'hr',
#   'sr',
#   'resolution',
#   'super'],
#  ['reconstruction',
#   'variational',
#   'blur',
#   'variation',
#   'deconvolution',
#   'denoising',
#   'tv',
#   'deblurring',
#   'restoration',
#   'regularization'],
#  ['filters',
#   'pf',
#   'gaussian',
#   'unscented',
#   'phd',
#   'target',
#   'tracking',
#   'particle',
#   'kalman',
#   'filter'],
#  ['bilateral',
#   'filtering',
#   'edges',
#   'filter',
#   'noise',
#   'bf',
#   'smoothing',
#   'anisotropic',
#   'diffusion',
#   'denoising'],
#  ['pixel',
#   'pepper',
#   'filter',
#   'median',
#   'noisy',
#   'corrupted',
#   'pixels',
#   'nlm',
#   'noise',
#   'impulse'],
#  ['components',
#   'series',
#   'racing',
#   'independent',
#   'separation',
#   'entropy',
#   'jica',
#   'without',
#   'ica',
#   'abstract'],
#  ['separation',
#   'jointly',
#   'beamforming',
#   'blind',
#   'computes',
#   'constant',
#   'diagonalization',
#   'noniterative',
#   'acma',
#   'modulus'],
#  ['convolutive',
#   'signals',
#   'source',
#   'mixing',
#   'sources',
#   'mixtures',
#   'blind',
#   'bss',
#   'separation',
#   'ica'],
#  ['conflicts',
#   'ta',
#   'cad',
#   'document',
#   'groupware',
#   'editing',
#   'widget',
#   'collaboration',
#   'consistency',
#   'collaborative'],
#  ['market',
#   'pricing',
#   'stock',
#   'option',
#   'volatility',
#   'asset',
#   'investment',
#   'financial',
#   'risk',
#   'portfolio'],
#  ['goals',
#   'oriented',
#   'norms',
#   'intelligent',
#   'coordination',
#   'bdi',
#   'multiagent',
#   'mas',
#   'agents',
#   'agent'],
#  ['nonvolatile',
#   'magnetic',
#   'rram',
#   'torque',
#   'write',
#   'spin',
#   'ram',
#   'mtj',
#   'mram',
#   'stt'],
#  ['tmsm',
#   'affinity',
#   'population',
#   'idiotypic',
#   'antibodies',
#   'artificial',
#   'antigen',
#   'antibody',
#   'ais',
#   'immune'],
#  ['scb',
#   'meta',
#   'tphs',
#   'nehs',
#   'optimization',
#   'harmonies',
#   'search',
#   'hsa',
#   'hs',
#   'harmony'],
#  ['tracking',
#   'head',
#   'deaf',
#   'recognition',
#   'hand',
#   'sign',
#   'eye',
#   'gestures',
#   'gesture',
#   'gaze'],
#  ['vehicle',
#   'ride',
#   'road',
#   'sctm',
#   'path',
#   'paths',
#   'traffic',
#   'route',
#   'shortest',
#   'travel'],
#  ['crossover',
#   'coevolutionary',
#   'programming',
#   'evolutionary',
#   'bloat',
#   'grammatical',
#   'coevolution',
#   'fitness',
#   'genetic',
#   'gp'],
#  ['pixels',
#   'babde',
#   'text',
#   'thresholding',
#   'foreground',
#   'documents',
#   'background',
#   'bleed',
#   'document',
#   'binarization'],
#  ['atomic',
#   'contention',
#   'synchronization',
#   'concurrent',
#   'transaction',
#   'tm',
#   'stm',
#   'transactions',
#   'lock',
#   'transactional'],
#  ['ocr',
#   'lines',
#   'caption',
#   'scene',
#   'extraction',
#   'characters',
#   'regions',
#   'document',
#   'character',
#   'text'],
#  ['writer',
#   'handwritten',
#   'line',
#   'offline',
#   'pen',
#   'genuine',
#   'forgeries',
#   'signatures',
#   'verification',
#   'signature'],
#  ['script',
#   'text',
#   'word',
#   'segmentation',
#   'arabic',
#   'recognition',
#   'characters',
#   'handwriting',
#   'character',
#   'handwritten'],
#  ['skeletal',
#   'characters',
#   'keyframe',
#   'posture',
#   'character',
#   'motions',
#   'animations',
#   'animation',
#   'postures',
#   'motion'],
#  ['solutions',
#   'dominated',
#   'optimization',
#   'moea',
#   'objectives',
#   'nsga',
#   'evolutionary',
#   'multiobjective',
#   'objective',
#   'pareto'],
#  ['singular',
#   'symmetric',
#   'approximation',
#   'tucker',
#   'matrices',
#   'decomposition',
#   'rank',
#   'multilinear',
#   'tensors',
#   'tensor'],
#  ['sensors',
#   'strain',
#   'film',
#   'sensor',
#   'thermal',
#   'fiber',
#   'solder',
#   'electrodes',
#   'temperature',
#   'electrode'],
#  ['pso',
#   'migration',
#   'histopathological',
#   'economic',
#   'cso',
#   'valve',
#   'dispatch',
#   'eld',
#   'biogeography',
#   'bbo'],
#  ['broadcasting',
#   'items',
#   'client',
#   'disks',
#   'requests',
#   'dissemination',
#   'schedule',
#   'item',
#   'clients',
#   'broadcast'],
#  ['mutation',
#   'benchmark',
#   'population',
#   'optimization',
#   'evolution',
#   'abc',
#   'de',
#   'particle',
#   'swarm',
#   'pso'],
#  ['population',
#   'genetic',
#   'offspring',
#   'migration',
#   'pbil',
#   'fitness',
#   'evolutionary',
#   'ea',
#   'eas',
#   'mutation'],
#  ['sphere',
#   'nes',
#   'λopt',
#   'strength',
#   'fitness',
#   'cma',
#   'adaptation',
#   'evolution',
#   'mutation',
#   'es'],
#  ['sciencecaching',
#   'wiki',
#   'contributions',
#   'edits',
#   'suggestbot',
#   'vandalism',
#   'contributors',
#   'editors',
#   'articles',
#   'wikipedia'],
#  ['dielectric',
#   'fabricated',
#   'db',
#   'patch',
#   'radiation',
#   'microstrip',
#   'band',
#   'thz',
#   'ghz',
#   'antenna'],
#  ['simulink',
#   'transmission',
#   'homeplug',
#   'grid',
#   'broadband',
#   'line',
#   'g3',
#   'lptv',
#   'mimo',
#   'plc'],
#  ['amvi',
#   'lincmb',
#   'imputing',
#   'missingness',
#   'imputed',
#   'impute',
#   'knn',
#   'values',
#   'missing',
#   'imputation'],
#  ['pilp',
#   'entailment',
#   'lifted',
#   'prism',
#   'hypothesis',
#   'subsumption',
#   'logic',
#   'inductive',
#   'probabilistic',
#   'ilp'],
#  ['tempo',
#   'pitch',
#   'midi',
#   'song',
#   'singing',
#   'melody',
#   'songs',
#   'audio',
#   'musical',
#   'music'],
#  ['outages',
#   'gnss',
#   'sins',
#   'imu',
#   'mems',
#   'positioning',
#   'inertial',
#   'navigation',
#   'gps',
#   'ins'],
#  ['gps',
#   'beidou',
#   'ionospheric',
#   'isb',
#   'positioning',
#   'navigation',
#   'satellites',
#   'satellite',
#   'bds',
#   'gnss'],
#  ['sensor',
#   'calibration',
#   'orientation',
#   'kalman',
#   'imu',
#   'gyroscope',
#   'attitude',
#   'magnetic',
#   'magnetometer',
#   'inertial'],
#  ['sybil',
#   'hoc',
#   'security',
#   'vehicle',
#   'privacy',
#   'vanet',
#   'vehicles',
#   'authentication',
#   'vanets',
#   'vehicular'],
#  ['traffic',
#   'safety',
#   'maneuvers',
#   'vehicles',
#   'drivers',
#   'road',
#   'vehicle',
#   'driving',
#   'lane',
#   'driver'],
#  ['drivers',
#   'eco',
#   'vehicle',
#   'merging',
#   'driving',
#   'traffic',
#   'intersections',
#   'fuel',
#   'intersection',
#   'vehicles'],
#  ['technologies',
#   'citation',
#   'documents',
#   'inventions',
#   'technological',
#   'citations',
#   'infringement',
#   'technology',
#   'patents',
#   'patent'],
#  ['science',
#   'scientific',
#   'articles',
#   'publication',
#   'papers',
#   'journal',
#   'publications',
#   'citations',
#   'journals',
#   'citation'],
#  ['natural',
#   'utterances',
#   'initiative',
#   'acts',
#   'conversational',
#   'speech',
#   'dialogues',
#   'spoken',
#   'dialog',
#   'dialogue'],
#  ['clips',
#   'facial',
#   'physiological',
#   'eeg',
#   'emotional',
#   'affective',
#   'emotions',
#   'arousal',
#   'valence',
#   'emotion'],
#  ['9im',
#   'relation',
#   'temporal',
#   'cardinal',
#   'topological',
#   'spatial',
#   'algebra',
#   'qualitative',
#   'reasoning',
#   'relations'],
#  ['cμ',
#   'olla',
#   'approachability',
#   'adversarial',
#   'mab',
#   'arms',
#   'bandits',
#   'armed',
#   'bandit',
#   'regret'],
#  ['iteration',
#   'nonlinear',
#   'jacobi',
#   'hamilton',
#   'nns',
#   'bellman',
#   'dhp',
#   'nn',
#   'adp',
#   'critic'],
#  ['clinical',
#   'medical',
#   'meddra',
#   'semantic',
#   'terminology',
#   'concepts',
#   'terminologies',
#   'ct',
#   'umls',
#   'snomed'],
#  ['hedcss',
#   'heterogeneous',
#   'tasks',
#   'duplication',
#   'processors',
#   'schedule',
#   'task',
#   'multiprocessor',
#   'dag',
#   'scheduling'],
#  ['encoding',
#   'evolving',
#   'ne',
#   'brains',
#   'evolutionary',
#   'evolve',
#   'evolved',
#   'anns',
#   'neuroevolution',
#   'hyperneat'],
#  ['pd',
#   'strategies',
#   'games',
#   'players',
#   'defectors',
#   'game',
#   'punishment',
#   'cooperation',
#   'prisoner',
#   'dilemma'],
#  ['tracking',
#   'trajectory',
#   'manipulator',
#   'vision',
#   'jacobian',
#   'ibvs',
#   'robot',
#   'visual',
#   'camera',
#   'servoing'],
#  ['xlsc',
#   'spdml',
#   'simulator',
#   'discrete',
#   'uml',
#   'specification',
#   'modeling',
#   'event',
#   'formalism',
#   'devs'],
#  ['preference',
#   'schools',
#   'gale',
#   'preferences',
#   'shapley',
#   'sided',
#   'marriage',
#   'matchings',
#   'matching',
#   'stable'],
#  ['arenas',
#   'played',
#   'reachability',
#   'bwr',
#   'game',
#   'determinacy',
#   'players',
#   'player',
#   'games',
#   'winning'],
#  ['buyers',
#   'bids',
#   'sellers',
#   'seller',
#   'price',
#   'bid',
#   'bidding',
#   'bidders',
#   'auctions',
#   'auction'],
#  ['stable',
#   'buyers',
#   'buyer',
#   'lccm',
#   'game',
#   'agent',
#   'agents',
#   'formation',
#   'coalitions',
#   'coalition'],
#  ['payoff',
#   'anarchy',
#   'shapley',
#   'player',
#   'equilibria',
#   'players',
#   'equilibrium',
#   'game',
#   'nash',
#   'games'],
#  ['ar',
#   'perceptual',
#   'texture',
#   'skin',
#   'fingertip',
#   'roughness',
#   'force',
#   'perception',
#   'touch',
#   'haptic'],
#  ['sender',
#   'timing',
#   'ecus',
#   'drtos',
#   'schedule',
#   'slot',
#   'bus',
#   'triggered',
#   'automotive',
#   'flexray'],
#  ['vehicles',
#   'coverage',
#   'haps',
#   'ground',
#   'altitude',
#   'terrestrial',
#   'unmanned',
#   'aerial',
#   'uavs',
#   'uav'],
#  ['caches',
#   'mru',
#   'mbpta',
#   'probabilistic',
#   'lru',
#   'pwcet',
#   'execution',
#   'worst',
#   'timing',
#   'wcet'],
#  ['actor',
#   'pgan',
#   'buffers',
#   'sdfgs',
#   'synchronous',
#   'actors',
#   'buffer',
#   'sdfg',
#   'sdf',
#   'dataflow'],
#  ['expression',
#   'wild',
#   'spontaneous',
#   'affective',
#   'emotions',
#   'ebook',
#   'expressions',
#   'emotional',
#   'emotion',
#   'facial'],
#  ['task',
#   'preemptive',
#   'criticality',
#   'deadlines',
#   'priority',
#   'edf',
#   'deadline',
#   'tasks',
#   'scheduling',
#   'schedulability'],
#  ['processor',
#   'battery',
#   'scheduling',
#   'savings',
#   'energy',
#   'dpm',
#   'consumption',
#   'scaling',
#   'voltage',
#   'dvs'],
#  ['haralick',
#   'terrain',
#   'clbp',
#   'memoization',
#   'gray',
#   'textures',
#   'co',
#   'occurrence',
#   'glcm',
#   'texture'],
#  ['training',
#   'irbm',
#   'hidden',
#   'autoencoders',
#   'deep',
#   'restricted',
#   'rbms',
#   'dbn',
#   'boltzmann',
#   'rbm'],
#  ['conditional',
#   'inference',
#   'variables',
#   'independence',
#   'learnable',
#   'pac',
#   'bns',
#   'causal',
#   'bn',
#   'bayesian'],
#  ['integration',
#   'interlaced',
#   'nets',
#   'weighted',
#   'lattice',
#   'worst',
#   'weights',
#   'qmc',
#   'discrepancy',
#   'tractability'],
#  ['development',
#   'tdd',
#   'tests',
#   'bridges',
#   'sundance',
#   'butch',
#   'acceptance',
#   'automation',
#   'article',
#   'page'],
#  ['inductive',
#   'sp',
#   'imn',
#   'wnpt',
#   'ipt',
#   'coil',
#   'resonant',
#   'transfer',
#   'coils',
#   'wpt'],
#  ['sensorless',
#   'flux',
#   'pmsm',
#   'permanent',
#   'induction',
#   'torque',
#   'magnet',
#   'motor',
#   'stator',
#   'rotor'],
#  ['dfigs',
#   'lvrt',
#   'reactive',
#   'generator',
#   'turbine',
#   'wecs',
#   'turbines',
#   'dfig',
#   'farm',
#   'wind'],
#  ['purchasing',
#   'tesn',
#   'vs',
#   'oem',
#   'company',
#   'chain',
#   'criteria',
#   'supply',
#   'suppliers',
#   'supplier'],
#  ['asynchronous',
#   'exploration',
#   'gathering',
#   'robot',
#   'ring',
#   'move',
#   'anonymous',
#   'agents',
#   'robots',
#   'rendezvous'],
#  ['attributes',
#   'approximations',
#   'pawlak',
#   'sets',
#   'covering',
#   'reduct',
#   'attribute',
#   'granules',
#   'granular',
#   'rough'],
#  ['traffic',
#   'fabric',
#   'port',
#   'ports',
#   'buffers',
#   'buffer',
#   'packet',
#   'switches',
#   'queued',
#   'switch'],
#  ['norms',
#   'ql',
#   'contrapositive',
#   'detour',
#   'qip',
#   'soft',
#   'contrapositivisation',
#   'implication',
#   'fuzzy',
#   'implications'],
#  ['valued',
#   'hesitant',
#   'criteria',
#   'interval',
#   'preference',
#   'making',
#   'decision',
#   'linguistic',
#   'intuitionistic',
#   'fuzzy'],
#  ['meter',
#   'consumption',
#   'usage',
#   'tooling',
#   'bos',
#   'households',
#   'electricity',
#   'appliances',
#   'household',
#   'appliance'],
#  ['ubicomp',
#   'ambient',
#   'devices',
#   'awareness',
#   'smart',
#   'pervasive',
#   'ami',
#   'ubiquitous',
#   'aware',
#   'context'],
#  ['orca',
#   'stimulation',
#   'ins',
#   'manis',
#   'rothman',
#   'axon',
#   'isis',
#   'nerve',
#   'axons',
#   'neurons'],
#  ['spikes',
#   'plasticity',
#   'synapses',
#   'neuronal',
#   'firing',
#   'neuron',
#   'spiking',
#   'synaptic',
#   'spike',
#   'neurons'],
#  ['interface',
#   'subjects',
#   'imagery',
#   'motor',
#   'p300',
#   'bcis',
#   'ssvep',
#   'brain',
#   'eeg',
#   'bci'],
#  ['idempotent',
#   'uninorm',
#   'conorms',
#   'conorm',
#   'bounded',
#   'norms',
#   'lattice',
#   'lattices',
#   'distributive',
#   'uninorms'],
#  ['ideal',
#   'sequences',
#   'fuzzy',
#   'numbers',
#   'convergence',
#   'lacunary',
#   'spaces',
#   'compactness',
#   'bornology',
#   'updelta'],
#  ['iouts',
#   'mac',
#   'nodes',
#   'sink',
#   'routing',
#   'uwsn',
#   'sensor',
#   'acoustic',
#   'uwsns',
#   'underwater'],
#  ['closed',
#   'affine',
#   'controller',
#   'loop',
#   'constraints',
#   'terminal',
#   'receding',
#   'horizon',
#   'predictive',
#   'mpc'],
#  ['wavelet',
#   'emd',
#   'rolling',
#   'faults',
#   'bearings',
#   'gear',
#   'diagnosis',
#   'vibration',
#   'fault',
#   'bearing'],
#  ['dr',
#   'air',
#   'thermal',
#   'building',
#   'conditioning',
#   'heating',
#   'ventilation',
#   'comfort',
#   'buildings',
#   'hvac'],
#  ['patient',
#   'interictal',
#   'electroencephalogram',
#   'patients',
#   'ictal',
#   'epileptic',
#   'seizures',
#   'epilepsy',
#   'eeg',
#   'seizure'],
#  ['signal',
#   'signals',
#   'hilbert',
#   'bemd',
#   'imf',
#   'empirical',
#   'mode',
#   'decomposition',
#   'imfs',
#   'emd'],
#  ['retailers',
#   'production',
#   'supplier',
#   'manufacturer',
#   'price',
#   'demand',
#   'chain',
#   'retailer',
#   'supply',
#   'inventory'],
#  ['facilities',
#   'logistics',
#   'centers',
#   'transportation',
#   'milp',
#   'facility',
#   'costs',
#   'whey',
#   'chain',
#   'supply'],
#  ['centromeres',
#   'dcj',
#   'chromosomes',
#   'translocations',
#   'sorting',
#   'reversals',
#   'rearrangements',
#   'genome',
#   'genomes',
#   'rearrangement'],
#  ['flights',
#   'transit',
#   'bunching',
#   'airlines',
#   'airports',
#   'airline',
#   'airport',
#   'passengers',
#   'bus',
#   'passenger'],
#  ['cardiac',
#   'electrocardiogram',
#   'bih',
#   'beats',
#   'beat',
#   'heart',
#   'arrhythmia',
#   'fetal',
#   'qrs',
#   'ecg'],
#  ['ecg',
#   'respiratory',
#   'osa',
#   'rr',
#   'pulse',
#   'apnea',
#   'ppg',
#   'heart',
#   'sleep',
#   'hrv'],
#  ['fiber',
#   'passive',
#   'upstream',
#   'epon',
#   'onu',
#   'olt',
#   'onus',
#   'optical',
#   'pons',
#   'pon'],
#  ['org',
#   'xlink',
#   'w3',
#   'xmlns',
#   'rsa',
#   'eons',
#   'italic',
#   'elastic',
#   'spectrum',
#   'optical'],
#  ['brake',
#   'tyre',
#   'friction',
#   'road',
#   'lateral',
#   'yaw',
#   'wheel',
#   'braking',
#   'vehicle',
#   'tire'],
#  ['loss',
#   'ingress',
#   'packet',
#   'contention',
#   'bursts',
#   'switching',
#   'wavelength',
#   'optical',
#   'obs',
#   'burst'],
#  ['backup',
#   'restoration',
#   'lightpaths',
#   'grooming',
#   'protection',
#   'lightpath',
#   'wavelengths',
#   'optical',
#   'wdm',
#   'wavelength'],
#  ['weights',
#   'recurrent',
#   'reservoirs',
#   'crj',
#   'readout',
#   'rc',
#   'esns',
#   'echo',
#   'esn',
#   'reservoir'],
#  ['overlapping',
#   'subsets',
#   'microarray',
#   'expression',
#   'bicluster',
#   'plaid',
#   'gene',
#   'genes',
#   'biclusters',
#   'biclustering'],
#  ['v2g',
#   'pevs',
#   'vehicle',
#   'pev',
#   'stations',
#   'vehicles',
#   'electric',
#   'evs',
#   'ev',
#   'charging'],
#  ['prosumers',
#   'market',
#   'price',
#   'grid',
#   'demand',
#   'pricing',
#   'smart',
#   'consumers',
#   'dr',
#   'electricity'],
#  ['reactive',
#   'islanded',
#   'dg',
#   'pv',
#   'dgs',
#   'droop',
#   'renewable',
#   'voltage',
#   'microgrids',
#   'microgrid'],
#  ['alignment',
#   'sequences',
#   'pseudoknot',
#   'molecules',
#   'folding',
#   'structures',
#   'rnas',
#   'pseudoknots',
#   'secondary',
#   'rna'],
#  ['rectifier',
#   'modulation',
#   'switching',
#   'pwm',
#   'ac',
#   'converters',
#   'inverter',
#   'dc',
#   'voltage',
#   'converter'],
#  ['maximum',
#   'modules',
#   'irradiance',
#   'shading',
#   'solar',
#   'dc',
#   'mpp',
#   'photovoltaic',
#   'mppt',
#   'pv'],
#  ['side',
#   'therapeutic',
#   'targets',
#   'diseases',
#   'ddis',
#   'repositioning',
#   'combinations',
#   'disease',
#   'drugs',
#   'drug'],
#  ['r2r',
#   'bots',
#   'laxity',
#   'agv',
#   'fdi',
#   'codeset',
#   'fuzzy',
#   'slack',
#   'article',
#   'page'],
#  ['attacker',
#   'cfi',
#   'gadgets',
#   'pointers',
#   'attack',
#   'code',
#   'attacks',
#   'stack',
#   'return',
#   'rop'],
#  ['policy',
#   'slot',
#   'queue',
#   'transmission',
#   'packets',
#   'delay',
#   'maxweight',
#   'scheduling',
#   'packet',
#   'deadline'],
#  ['unsaturated',
#   'dengue',
#   'adaptive',
#   'unsat',
#   'soils',
#   '_6',
#   'fuzzy',
#   'inference',
#   'neuro',
#   'anfis'],
#  ['article',
#   'inference',
#   'membership',
#   'sugeno',
#   'rules',
#   'interpretability',
#   'page',
#   'rule',
#   'tsk',
#   'fuzzy'],
#  ['phone',
#   'keystrokes',
#   'pin',
#   'biometrics',
#   'identity',
#   'password',
#   'touch',
#   'biometric',
#   'authentication',
#   'keystroke'],
#  ['frieze',
#   'sqq',
#   'person',
#   'clothing',
#   'body',
#   'walking',
#   'silhouettes',
#   'recognition',
#   'silhouette',
#   'gait'],
#  ['receiver',
#   'tr',
#   'multipath',
#   'impulse',
#   'pulses',
#   'ir',
#   'pulse',
#   'wideband',
#   'ultra',
#   'uwb'],
#  ['flux',
#   'kinetic',
#   'enzymes',
#   'pathway',
#   'reactions',
#   'metabolite',
#   'pathways',
#   'metabolites',
#   'metabolism',
#   'metabolic'],
#  ['axial',
#   'fpe',
#   'motor',
#   'engine',
#   'reciprocating',
#   'stiction',
#   'rod',
#   'hydraulic',
#   'valve',
#   'piston'],
# ...
#   'tier',
#   'base',
#   'lte',
#   'macrocell',
#   'interference',
#   'femtocells',
#   'cell',
#   'macro',
#   'femtocell'],
#  ['uio',
#   'sequences',
#   'mbt',
#   'test',
#   'reset',
#   'checking',
#   'cpss',
#   'fsm',
#   'testing',
#   'fsms'],
#  ['games',
#   'young',
#   'rapido',
#   'tangible',
#   'tabletops',
#   'embodied',
#   'interactive',
#   'dancer',
#   'tabletop',
#   'children'],
#  ['cultural',
#   'visit',
#   'festival',
#   'heritage',
#   'exhibitions',
#   'exhibition',
#   'visitor',
#   'museums',
#   'visitors',
#   'museum'],
#  ['detailed',
#   'placers',
#   'memos',
#   'tdp',
#   'placer',
#   'congestion',
#   'routing',
#   'routability',
#   'wirelength',
#   'placement'],
#  ['patterning',
#   'slicing',
#   'opc',
#   'modules',
#   'wire',
#   'floorplans',
#   'layout',
#   'flare',
#   'floorplanning',
#   'floorplan'],
#  ['manets',
#   'mobility',
#   'protocols',
#   'protocol',
#   'aodv',
#   'manet',
#   'route',
#   'ad',
#   'hoc',
#   'routing'],
#  ['chip',
#   'biopotential',
#   'mu',
#   'nef',
#   'khz',
#   'neural',
#   'cmos',
#   'implantable',
#   'amplifier',
#   'recording'],
#  ['wrinkles',
#   'materials',
#   'shearing',
#   'volumetric',
#   'material',
#   'elastic',
#   'rods',
#   'deformations',
#   'deformation',
#   'cloth'],
#  ['hydrodynamics',
#   'bubble',
#   'surface',
#   'fluids',
#   'soap',
#   'particles',
#   'smoke',
#   'particle',
#   'bubbles',
#   'fluid'],
#  ['background',
#   'visual',
#   'discriminative',
#   'target',
#   'object',
#   'occlusion',
#   'trackers',
#   'appearance',
#   'tracker',
#   'tracking'],
#  ['qam',
#   'bit',
#   'constellations',
#   'interleaved',
#   'decoding',
#   'turbo',
#   'constellation',
#   'modulation',
#   'coded',
#   'bicm'],
#  ['operative',
#   'ultrasound',
#   'deformation',
#   'ct',
#   'resection',
#   'surgical',
#   'surgery',
#   'registration',
#   'preoperative',
#   'intraoperative'],
#  ['tc',
#   'supply',
#   'circuit',
#   'cmos',
#   'ppm',
#   'reference',
#   'bgr',
#   'bandgap',
#   'temperature',
#   'voltage'],
#  ['scenes',
#   'object',
#   'tracklets',
#   'hog',
#   'occlusions',
#   'tracklet',
#   'occlusion',
#   'tracking',
#   'pedestrians',
#   'pedestrian'],
#  ['sensor',
#   'packet',
#   'nodes',
#   'grees',
#   'packets',
#   'flooding',
#   'wsns',
#   'delivery',
#   'tra',
#   'routing'],
#  ['wireless',
#   'energy',
#   'sensors',
#   'sink',
#   'coverage',
#   'nodes',
#   'wsns',
#   'wsn',
#   'lifetime',
#   'sensor'],
#  ['triangles',
#   'coding',
#   'hexashrink',
#   '3d',
#   'vertices',
#   'geometry',
#   'progressive',
#   'compression',
#   'meshes',
#   'mesh'],
#  ['graphics',
#   'surface',
#   'reflectance',
#   'shading',
#   'volume',
#   'lighting',
#   'ray',
#   'light',
#   'illumination',
#   'rendering'],
#  ['qc',
#   'density',
#   'decoders',
#   'code',
#   'decoder',
#   'check',
#   'parity',
#   'decoding',
#   'codes',
#   'ldpc'],
#  ['interleaving',
#   'biting',
#   'code',
#   'decoding',
#   'convolutional',
#   'trellis',
#   'codes',
#   'interleavers',
#   'turbo',
#   'interleaver'],
#  ['dbc',
#   'mhz',
#   'phase',
#   'vco',
#   'cmos',
#   'oscillator',
#   'locked',
#   'clock',
#   'pll',
#   'jitter'],
#  ['pa', 'gain', 'rf', 'mixer', 'dbm', 'ghz', 'cmos', 'lna', 'amplifier', 'db'],
#  ['comparator',
#   'converter',
#   'bit',
#   'cmos',
#   'digital',
#   'modulator',
#   'adcs',
#   'analog',
#   'dac',
#   'adc'],
#  ['motion',
#   'tracker',
#   'particle',
#   'targets',
#   'track',
#   'appearance',
#   'object',
#   'occlusion',
#   'occlusions',
#   'tracking'],
#  ['pixels',
#   'surveillance',
#   'scene',
#   'illumination',
#   'objects',
#   'pixel',
#   'moving',
#   'subtraction',
#   'foreground',
#   'background'],
#  ['gdof',
#   'ifc',
#   'bounds',
#   'region',
#   'outer',
#   'channel',
#   'gaussian',
#   'regime',
#   'capacity',
#   'interference'],
#  ['channel',
#   'degrees',
#   'csit',
#   'freedom',
#   'transmitters',
#   'mimo',
#   'alignment',
#   'dof',
#   'interference',
#   'ia'],
#  ['display',
#   'keyboards',
#   'pointing',
#   'menu',
#   'gestures',
#   'mouse',
#   'entry',
#   'screen',
#   'keyboard',
#   'touch'],
#  ['augmented',
#   'head',
#   'sickness',
#   'ss',
#   'lag',
#   'virtual',
#   'ar',
#   'hmd',
#   'reality',
#   'vr'],
#  ['mild',
#   'impairment',
#   'brain',
#   'neuroimaging',
#   'mri',
#   'adni',
#   'disease',
#   'ad',
#   'alzheimer',
#   'mci'],
#  ['mapping',
#   'camera',
#   'odometry',
#   'landmarks',
#   'navigation',
#   'landmark',
#   'map',
#   'localization',
#   'robot',
#   'slam'],
#  ['vision',
#   'pose',
#   'calibrated',
#   'reconstruction',
#   'correspondences',
#   '3d',
#   'homography',
#   'cameras',
#   'calibration',
#   'camera'],
#  ['log',
#   'prom',
#   'declarative',
#   'workflow',
#   'event',
#   'processes',
#   'compliance',
#   'mining',
#   'logs',
#   'business'],
#  ['triangulation',
#   'geometry',
#   'meshing',
#   'parameterization',
#   'delaunay',
#   'surfaces',
#   'surface',
#   'voronoi',
#   'meshes',
#   'mesh'],
#  ['hhk',
#   'offsets',
#   'planes',
#   'parametrization',
#   'ruled',
#   'moving',
#   'singularities',
#   'curves',
#   'curve',
#   'rational'],
#  ['bezier',
#   'rational',
#   'interpolation',
#   'curve',
#   'subdivision',
#   'curves',
#   'bézier',
#   'splines',
#   'surfaces',
#   'spline'],
#  ['channels',
#   'sight',
#   'los',
#   'capacity',
#   'channel',
#   'rician',
#   'fading',
#   'antennas',
#   'antenna',
#   'mimo'],
#  ['epileptogenic',
#   'brain',
#   'reml',
#   'sources',
#   'source',
#   'haemodynamic',
#   'priors',
#   'fmri',
#   'meg',
#   'eeg'],
#  ['answering',
#   'convolutional',
#   'words',
#   'attention',
#   'text',
#   'question',
#   'semantic',
#   'sentence',
#   'word',
#   'embeddings'],
#  ['blood',
#   'disc',
#   'oct',
#   'diabetic',
#   'optic',
#   'retinopathy',
#   'fundus',
#   'vessels',
#   'vessel',
#   'retinal'],
#  ['ratings',
#   'preferences',
#   'rating',
#   'filtering',
#   'item',
#   'collaborative',
#   'items',
#   'recommendations',
#   'recommender',
#   'recommendation'],
#  ['category',
#   'idf',
#   'csa',
#   'geoscience',
#   'words',
#   'document',
#   'word',
#   'documents',
#   'categorization',
#   'text'],
#  ['probability',
#   'rician',
#   'expression',
#   'derived',
#   'combining',
#   'cdf',
#   'diversity',
#   'expressions',
#   'nakagami',
#   'fading'],
#  ['csi',
#   'transmitter',
#   'fading',
#   'beamforming',
#   'antenna',
#   'channel',
#   'transmit',
#   'antennas',
#   'precoding',
#   'mimo'],
#  ['zeros',
#   'simo',
#   'impulse',
#   'channels',
#   'channel',
#   'modulus',
#   'equalizer',
#   'equalization',
#   'blind',
#   'cma'],
#  ['mc',
#   'multiuser',
#   'mai',
#   'multipath',
#   'division',
#   'rake',
#   'receiver',
#   'spreading',
#   'ds',
#   'cdma'],
#  ['management',
#   'interoperability',
#   'enterprises',
#   'strategic',
#   'architecture',
#   'eam',
#   'eaim',
#   'business',
#   'enterprise',
#   'ea'],
#  ['3d',
#   'anatomical',
#   'mutual',
#   'ct',
#   'images',
#   'landmark',
#   'intensity',
#   'rigid',
#   'deformation',
#   'registration'],
#  ['template',
#   'vervet',
#   'tissue',
#   'segmentations',
#   'mr',
#   'mri',
#   'brain',
#   'segmentation',
#   'atlases',
#   'atlas'],
#  ['activity',
#   'left',
#   'regions',
#   'resting',
#   'activation',
#   'functional',
#   'connectivity',
#   'cortex',
#   'brain',
#   'fmri'],
#  ['infants',
#   'infant',
#   'macruise',
#   'preterm',
#   'parcellation',
#   'vivo',
#   'atlas',
#   'brain',
#   'mri',
#   'cortical'],
#  ['segmentation',
#   'centerline',
#   'artery',
#   'angiography',
#   'lumen',
#   'arteries',
#   'vascular',
#   'vessels',
#   'coronary',
#   'vessel'],
#  ['shape',
#   'rv',
#   'ct',
#   'atlas',
#   'ventricle',
#   'heart',
#   'segmentation',
#   'liver',
#   'cardiac',
#   'kidney'],
#  ['tractography',
#   'mri',
#   'dmri',
#   'fa',
#   'white',
#   'tract',
#   'matter',
#   'dti',
#   'fiber',
#   'diffusion'],
#  ['myelin',
#   'healthy',
#   'hippocampal',
#   'white',
#   'hippocampus',
#   'gray',
#   'brain',
#   'age',
#   'cortical',
#   'matter'],
#  ['bones',
#   'segmentations',
#   'ct',
#   'shape',
#   'mr',
#   'abdominal',
#   'supraspinatus',
#   'fetal',
#   'vertebral',
#   'segmentation'],
#  ['gradient',
#   'images',
#   'boundaries',
#   'object',
#   'snakes',
#   'active',
#   'contours',
#   'segmentation',
#   'snake',
#   'contour'],
#  ['flickr',
#   'icio',
#   'cubelsi',
#   'resources',
#   'social',
#   'taggers',
#   'collaborative',
#   'tag',
#   'tags',
#   'tagging'],
#  ['multiplexing',
#   'modulation',
#   'gofdm',
#   'gfdm',
#   'cmfb',
#   'mcm',
#   'qam',
#   'multicarrier',
#   'ofdm',
#   'fbmc'],
#  ['companding',
#   'reduction',
#   'orthogonal',
#   'division',
#   'multiplexing',
#   'clipping',
#   'pts',
#   'peak',
#   'ofdm',
#   'papr'],
#  ['carrier',
#   'channel',
#   'bem',
#   'frequency',
#   'orthogonal',
#   'multiplexing',
#   'division',
#   'pilot',
#   'ici',
#   'ofdm'],
#  ['estimator',
#   'preamble',
#   'division',
#   'frequency',
#   'synchronization',
#   'symbol',
#   'carrier',
#   'ofdm',
#   'offset',
#   'cfo'],
#  ['automatically',
#   'extract',
#   'records',
#   'page',
#   'wrapper',
#   'extraction',
#   'wrappers',
#   'web',
#   'pages',
#   'html'],
#  ['dw',
#   'materialization',
#   'queries',
#   'multidimensional',
#   'warehouses',
#   'views',
#   'materialized',
#   'cube',
#   'warehouse',
#   'olap'],
#  ['word',
#   'eligibility',
#   'text',
#   'emphysema',
#   'document',
#   'dirichlet',
#   'latent',
#   'topics',
#   'topic',
#   'lda'],
#  ['isms',
#   'automotive',
#   '26262',
#   'vses',
#   'artprotest',
#   'standardization',
#   'standards',
#   '15504',
#   'iec',
#   'iso'],
#  ['contributors',
#   'source',
#   'seco',
#   'software',
#   'coss',
#   'developers',
#   'ecosystems',
#   'open',
#   'projects',
#   'oss'],
#  ['schemas',
#   'xquery',
#   'document',
#   'relational',
#   'queries',
#   'query',
#   'documents',
#   'xpath',
#   'schema',
#   'xml'],
#  ['authority',
#   'diffusionrank',
#   'hits',
#   'ranking',
#   'hyperlink',
#   'link',
#   'page',
#   'pagerank',
#   'web',
#   'pages'],
#  ['topic',
#   'focused',
#   'page',
#   'crawl',
#   'url',
#   'pages',
#   'web',
#   'crawlers',
#   'crawling',
#   'crawler'],
#  ['intents',
#   'session',
#   'intent',
#   'click',
#   'engines',
#   'queries',
#   'logs',
#   'query',
#   'engine',
#   'search'],
#  ['uris',
#   'triple',
#   'queries',
#   'stores',
#   'fulltext',
#   'semantic',
#   'query',
#   'triples',
#   'sparql',
#   'rdf'],
#  ['reasoner',
#   'el',
#   'ontologies',
#   'ontology',
#   'description',
#   'reasoning',
#   'logics',
#   'dls',
#   'owl',
#   'dl'],
#  ['databases',
#   'dcam',
#   'matching',
#   'sources',
#   'integration',
#   'semantic',
#   'schemas',
#   'schema',
#   'ontologies',
#   'ontology'],
#  ['vae',
#   'vocoder',
#   'spectral',
#   'speaker',
#   'vc',
#   'gmm',
#   'converted',
#   'voice',
#   'speech',
#   'conversion'],
#  ['relevant',
#   'ranking',
#   'ir',
#   'collections',
#   'relevance',
#   'query',
#   'trec',
#   'document',
#   'documents',
#   'retrieval'],
#  ['faq',
#   'causality',
#   'language',
#   'trec',
#   'questions',
#   'answers',
#   'answer',
#   'question',
#   'answering',
#   'qa'],
#  ['uris',
#   'uri',
#   'multimedia',
#   'heritage',
#   'needs',
#   'web',
#   'semantic',
#   'interlinking',
#   'lod',
#   'linked'],
#  ['mapping',
#   'concepts',
#   'domain',
#   'web',
#   'ontological',
#   'interoperability',
#   'knowledge',
#   'semantic',
#   'ontologies',
#   'ontology'],
#  ['scrum',
#   'organizations',
#   'lean',
#   'project',
#   'projects',
#   'teams',
#   'development',
#   'software',
#   'practices',
#   'agile'],
#  ['software',
#   'adaptivity',
#   'organic',
#   'requirements',
#   'adaptive',
#   'runtime',
#   'healing',
#   'adaptation',
#   'self',
#   'autonomic'],
#  ['boolean',
#   'solver',
#   'clause',
#   'unsatisfiable',
#   'maxsat',
#   'clauses',
#   'solvers',
#   'satisfiability',
#   'cnf',
#   'sat'],
#  ['search',
#   'doku',
#   'satisfaction',
#   'wcsp',
#   'csps',
#   'arc',
#   'consistency',
#   'ac3',
#   'constraint',
#   'csp'],
#  ['vocabulary',
#   'oov',
#   'std',
#   'broadcast',
#   'news',
#   'spoken',
#   'hindi',
#   'word',
#   'speech',
#   'asr'],
#  ['abstractive',
#   'text',
#   'extractive',
#   'rouge',
#   'summaries',
#   'sentence',
#   'document',
#   'sentences',
#   'summary',
#   'summarization'],
#  ['recognition',
#   'extraction',
#   'names',
#   'gazetteers',
#   'entities',
#   'crf',
#   'corpus',
#   'named',
#   'ner',
#   'entity'],
#  ['java',
#   'atomicity',
#   'program',
#   'jpf',
#   'pointer',
#   'deadlocks',
#   'debugging',
#   'race',
#   'programs',
#   'races'],
#  ['program',
#   'suites',
#   'faults',
#   'fault',
#   'coverage',
#   'suite',
#   'mutants',
#   'test',
#   'mutation',
#   'testing'],
#  ['static',
#   'jpf',
#   'testing',
#   'programs',
#   'java',
#   'fuzzing',
#   'program',
#   'veritesting',
#   'execution',
#   'symbolic'],
#  ['graphemes',
#   'lexicon',
#   'units',
#   'phonetic',
#   'pronunciation',
#   'acoustic',
#   'lexical',
#   'speech',
#   'subword',
#   'asr'],
#  ['room',
#   'speech',
#   'source',
#   'tdoa',
#   'reverberation',
#   'localization',
#   'binaural',
#   'microphones',
#   'microphone',
#   'sound'],
#  ['ordering',
#   'binary',
#   'verification',
#   'renement',
#   'sat',
#   'robdd',
#   'diagrams',
#   'diagram',
#   'bdds',
#   'bdd'],
#  ['phrase',
#   'language',
#   'machine',
#   'smt',
#   'word',
#   'translations',
#   'bilingual',
#   'mt',
#   'english',
#   'translation'],
#  ['recognition',
#   'clean',
#   'snr',
#   'spectral',
#   'vad',
#   'noisy',
#   'intelligibility',
#   'enhancement',
#   'noise',
#   'speech'],
#  ['verification',
#   'nist',
#   'cepstral',
#   'mel',
#   'speakers',
#   'mfcc',
#   'gmm',
#   'speech',
#   'plda',
#   'speaker'],
#  ['coreference',
#   'sense',
#   'lexical',
#   'semantic',
#   'nouns',
#   'wsd',
#   'disambiguation',
#   'verbs',
#   'noun',
#   'verb'],
#  ['grammars',
#   'corpus',
#   'parse',
#   'parsers',
#   'dependency',
#   'treebank',
#   'grammar',
#   'syntactic',
#   'parser',
#   'parsing'],
#  ['emphatic',
#   'dysarthric',
#   'speakers',
#   'fricative',
#   'voicing',
#   'hmm',
#   'nasal',
#   'vowel',
#   'speaker',
#   'speech'],
#  ['vowels',
#   'dialect',
#   'speakers',
#   'tts',
#   'english',
#   'prosodic',
#   'syllable',
#   'mandarin',
#   'accent',
#   'speech'],
#  ['copy',
#   'duplicates',
#   'bug',
#   'spape',
#   'cloning',
#   'bugs',
#   'code',
#   'cloned',
#   'clone',
#   'clones'],
#  ['democracy',
#   'citizen',
#   'participation',
#   'sector',
#   'ict',
#   'governments',
#   'governance',
#   'citizens',
#   'public',
#   'government'],
#  ['prognosability',
#   'fault',
#   'dess',
#   'supervisor',
#   'discrete',
#   'diagnosis',
#   'supervisory',
#   'event',
#   'diagnoser',
#   'diagnosability'],
#  ['places',
#   'liveness',
#   'reachability',
#   'timed',
#   'pns',
#   'pn',
#   'deadlock',
#   'net',
#   'nets',
#   'petri'],
#  ['defects',
#   'fault',
#   'prediction',
#   'bugs',
#   'cohesion',
#   'proneness',
#   'software',
#   'metrics',
#   'bug',
#   'defect'],
#  ['eclipse',
#   'null',
#   'software',
#   'maintainability',
#   'smell',
#   'projects',
#   'smells',
#   'code',
#   'refactorings',
#   'refactoring'],
#  ['languages',
#   'typed',
#   'type',
#   'proofs',
#   'rewriting',
#   'semantics',
#   'logics',
#   'proof',
#   'logic',
#   'calculus'],
#  ['student',
#   'massive',
#   'online',
#   'analytics',
#   'students',
#   'courses',
#   'learners',
#   'course',
#   'moocs',
#   'mooc'],
#  ['algebra',
#   'comet',
#   'skills',
#   'intelligent',
#   'hints',
#   'tutors',
#   'student',
#   'students',
#   'tutor',
#   'tutoring'],
#  ['self',
#   'friends',
#   'snss',
#   'adolescents',
#   'online',
#   'media',
#   'personality',
#   'social',
#   'sns',
#   'facebook'],
#  ['victimization',
#   'intolerance',
#   'loneliness',
#   'psu',
#   'adolescent',
#   'adolescents',
#   'smartphone',
#   'depression',
#   'internet',
#   'addiction'],
#  ['students',
#   'elements',
#   'tripadvisor',
#   'motivation',
#   'game',
#   'educational',
#   'motivational',
#   'engagement',
#   'gamified',
#   'gamification'],
#  ['decisions',
#   'spls',
#   'engineering',
#   'requirements',
#   'software',
#   'traceability',
#   'architectural',
#   'variability',
#   'spl',
#   'product'],
#  ['symbolic',
#   'abstraction',
#   'specification',
#   'checker',
#   'ltl',
#   'formal',
#   'automata',
#   'timed',
#   'verification',
#   'checking'],
#  ['online',
#   'factors',
#   'customer',
#   'trust',
#   'commerce',
#   'satisfaction',
#   'acceptance',
#   'adoption',
#   'intention',
#   'perceived'],
#  ['education',
#   'playing',
#   'griefing',
#   'play',
#   'skills',
#   'players',
#   'students',
#   'educational',
#   'games',
#   'game'],
#  ['curriculum',
#   'classroom',
#   'science',
#   'teachers',
#   'courses',
#   'education',
#   'student',
#   'teaching',
#   'course',
#   'students'],
#  ['language',
#   'languages',
#   'programming',
#   'aspectj',
#   'crosscutting',
#   'concerns',
#   'aspects',
#   'oriented',
#   'aop',
#   'aspect'],
#  ['nat2test',
#   'mechatronic',
#   'behaviour',
#   'statechart',
#   'diagrams',
#   'lscs',
#   'variabilities',
#   'marte',
#   'uml',
#   'statecharts'],
#  ['diagram',
#   'modeling',
#   'language',
#   'metamodel',
#   'transformation',
#   'formal',
#   'mde',
#   'ocl',
#   'diagrams',
#   'uml'],
#  ['dcap',
#   'grounded',
#   'innovation',
#   'maturity',
#   'intermediary',
#   'engagement',
#   'business',
#   'crowdsourcing',
#   'artifact',
#   'science'],
#  ['strategic',
#   'organizations',
#   'knowledge',
#   'outsourcing',
#   'business',
#   'erp',
#   'km',
#   'firms',
#   'firm',
#   'organizational']]

# %%
import pickle
with open('topics_d2v.pkl', 'wb') as f:
    pickle.dump(topics2, f)

# %%
# Get similar categories
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

distances = cosine_similarity(ctfidf, ctfidf)
np.fill_diagonal(distances, 0)
#distances[0].argmax()
distances[0]
print(topics[1])
print(topics[121])
# Out:
# ['für', 'den', 'eine', 'auf', 'zu', 'werden', 'von', 'die', 'der', 'und']
# ['log2', 'collision', 'stations', 'gossiping', 'radio', 'frac', 'log', 'rounds', 'broadcast', 'broadcasting']

# %%
ctfidf[2]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
result = pd.DataFrame([(index, distances[index].argmax()) for index in range(len(docs_per_class))],columns=["From", "To"])

# %%
result
# Out:
#      From   To
# 0       0    5
# 1       1  121
# 2       2  266
# 3       3  638
# 4       4  460
# ..    ...  ...
# 724   724  718
# 725   725  728
# 726   726  728
# 727   727  360
# 728   728  718
#
# [729 rows x 2 columns]

# %%
def _reduce_to_n_topics(documents: pd.DataFrame) -> pd.DataFrame:

        # Track which topics where originally merged
        if not self._merged_topics:
            self._merged_topics = []

        # Create topic similarity matrix
        similarities = cosine_similarity(self.c_tf_idf_)
        np.fill_diagonal(similarities, 0)

        # Find most similar topic to least common topic
        topics = documents.Topic.tolist().copy()
        mapped_topics = {}
        while len(self.get_topic_freq()) > self.nr_topics + self._outliers:
            topic_to_merge = self.get_topic_freq().iloc[-1].Topic
            topic_to_merge_into = np.argmax(similarities[topic_to_merge + self._outliers]) - self._outliers
            similarities[:, topic_to_merge + self._outliers] = -self._outliers
            self._merged_topics.append(topic_to_merge)

            # Update Topic labels
            documents.loc[documents.Topic == topic_to_merge, "Topic"] = topic_to_merge_into
            mapped_topics[topic_to_merge] = topic_to_merge_into
            self._update_topic_size(documents)

        # Map topics
        mapped_topics = {from_topic: to_topic for from_topic, to_topic in zip(topics, documents.Topic.tolist())}
        self.topic_mapper_.add_mappings(mapped_topics)

        # Update representations
        documents = self._sort_mappings_by_frequency(documents)
        self._extract_topics(documents)
        self._update_topic_size(documents)
        return documents

# %%
def get_topic_freq(self, topic: int = None) -> Union[pd.DataFrame, int]:
        
        check_is_fitted(self)
        if isinstance(topic, int):
            return self.topic_sizes_[topic]
        else:
            return pd.DataFrame(self.topic_sizes_.items(), columns=['Topic', 'Count']).sort_values("Count",
                                                                                                   ascending=False)
